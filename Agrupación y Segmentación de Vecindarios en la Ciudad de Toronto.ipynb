# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json, lxml
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
# import folium # map rendering library
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
try:
    import folium
except:
    # !pip install folium
    import folium

# %% [markdown]
# ## Part 1: Reading the data

# %%
url = 'http://zims-en.kiwix.campusafrica.gos.orange.com/wikipedia_en_all_nopic/A/List_of_postal_codes_of_Canada:_M'
source = requests.get(url).text
soup = BeautifulSoup(source)

table_data = soup.find('div', class_='mw-parser-output')
table = table_data.table.tbody

columns = ['PostalCode', 'Borough', 'Neighbourhood']
data = dict({key:[]*len(columns) for key in columns})

for row in table.find_all('tr'):
    for i,column in zip(row.find_all('td'),columns):
        i = i.text
        i = i.replace('\n', '')
        data[column].append(i)

df = pd.DataFrame.from_dict(data=data)[columns]
print(df.shape)
df.head()
# Out:
# (287, 3)
#   PostalCode           Borough     Neighbourhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %%
df = df[df['Borough'] != 'Not assigned'].reset_index(drop = True)
print('After dropping rows where borough is "Not assigned", Shape is: ',df.shape)
print('Number of rows where Neighbourhood is "Not assigned" but borough has value: ', 
      df[df['Neighbourhood'] == 'Not assigned'].shape[0])
# Out:
# After dropping rows where borough is "Not assigned", Shape is:  (210, 3)
# Number of rows where Neighbourhood is "Not assigned" but borough has value:  1

# %%
p, b, n = [], [], []
for postcode, borough, neigh in zip(df['PostalCode'], df['Borough'], df['Neighbourhood']):
    p.append(postcode)
    b.append(borough)
    if neigh == 'Not assigned':
        n.append(borough)
    else:
        n.append(neigh)

df = pd.DataFrame({'PostalCode': p, 'Borough': b, 'Neighbourhood':n})[columns]
print(df.shape)
df.head()
# Out:
# (210, 3)
#   PostalCode           Borough     Neighbourhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M6A        North York  Lawrence Heights
# 4        M6A        North York    Lawrence Manor

# %%
postcodes = df['PostalCode'].values
boroughs = df['Borough'].values
neighs = df['Neighbourhood'].values

#create a dictionary with keys as Postcode and Borough, keys of dictioaries are unique
dic = dict({(key1,key2): [] for key1, key2 in zip(postcodes, boroughs)})
print('Number of keys in the dictionary are: ', len(dic.keys()))

#filling the values of keys of dictionary
for postcode, borough, neigh in zip(postcodes,boroughs, neighs):
    key = (postcode, borough)
    dic[key].append(neigh)

df = pd.DataFrame(columns = ['Postal Code', 'Borough', 'Neighbourhood'])
for key, value in dic.items():
    postcode, borough, neig = key[0], key[1], value
    neig = ', '.join(neig)
    df = df.append({'Postal Code': postcode,
                     'Borough': borough,
                     'Neighbourhood': neig}, ignore_index = True)
print('Shape of final data is: ', df.shape)
df.head(10)
# Out:
# Number of keys in the dictionary are:  103
# Shape of final data is:  (103, 3)
#   Postal Code           Borough                     Neighbourhood
# 0         M3A        North York                         Parkwoods
# 1         M4A        North York                  Victoria Village
# 2         M5A  Downtown Toronto                      Harbourfront
# 3         M6A        North York  Lawrence Heights, Lawrence Manor
# 4         M7A      Queen's Park                      Queen's Park
# 5         M9A  Downtown Toronto                      Queen's Park
# 6         M1B       Scarborough                    Rouge, Malvern
# 7         M3B        North York                   Don Mills North
# 8         M4B         East York   Woodbine Gardens, Parkview Hill
# 9         M5B  Downtown Toronto          Ryerson, Garden District

# %%
# download the data of latitude and longitude: link provided by >>>>coursera
#!wget http://cocl.us/Geospatial_data
try:
    df['Latitude'] = lats
    df['Longitude'] = lons
except:
    latlon = pd.read_csv('Geospatial_data.csv')
    df = pd.merge(df, latlon, how= 'inner', on = 'Postal Code')
    
print(df.shape)
df.head(10)
# Out:
# (103, 5)
#   Postal Code           Borough                     Neighbourhood   Latitude  \
# 0         M3A        North York                         Parkwoods  43.753259
# 1         M4A        North York                  Victoria Village  43.725882
# 2         M5A  Downtown Toronto                      Harbourfront  43.654260
# 3         M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4         M7A      Queen's Park                      Queen's Park  43.662301
# 5         M9A  Downtown Toronto                      Queen's Park  43.667856
# 6         M1B       Scarborough                    Rouge, Malvern  43.806686
# 7         M3B        North York                   Don Mills North  43.745906
# 8         M4B         East York   Woodbine Gardens, Parkview Hill  43.706397
# 9         M5B  Downtown Toronto          Ryerson, Garden District  43.657162
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
# 5 -79.532242
# 6 -79.194353
# 7 -79.352188
# 8 -79.309937
# 9 -79.378937

# %%
address = 'Toronto, Ontario'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 43.6534817, -79.3839347.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bf8b773cdac988be23d10a3e3b79039 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bf8b773cdac988be23d10a3e3b79039&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5bf8b773cdac988be23d10a3e3b79039 = L.map(
#                 &quot;map_5bf8b773cdac988be23d10a3e3b79039&quot;,
#                 {
#                     center: [43.6563221, -79.3809161],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05ddfd536e2dae5fa04036c7c2d50cd0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5bf8b773cdac988be23d10a3e3b79039);
#
#
#             var circle_marker_dcd67b9d3ccd4d23db8fa2b4f7b8d869 = L.circleMarker(
#                 [43.7532586, -79.3296565],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5bf8b773cdac988be23d10a3e3b79039);
#
#
#         var popup_794560d61bd076d54d2ae7b303a53fbf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_07498138f38a9b6eeb50ee99fcead231 = $(`&lt;div id=&quot;html_07498138f38a9b6eeb50ee99fcead231&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parkwoods, North York&lt;/div&gt;`)[0];
#             popup_794560d61bd076d54d2ae7b303a53fbf.setContent(html_07498138f38a9b6eeb50ee99fcead231);
#
#
#         circle_marker_dcd67b9d3ccd4d23db8fa2b4f7b8d869.bindPopup(popup_794560d61bd076d54d2ae7b303a53fbf)
#         ;
#
#
#
#
#             var circle_marker_750437b0101a044533d2e0f2bdd028dc = L.circleMarker(
#                 [43.7258823, -79.3155716],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5bf8b773cdac988be23d10a3e3b79039);
#
#
#         var popup_23dfd4d5c832ae3ab8f54ba3472b9bff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_09c8f9ce7e27b5dfdfc3a7e886c7ddd3 = $(`&lt;div id=&quot;html_09c8f9ce7e27b5dfdfc3a7e886c7ddd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Victoria Village, North York&lt;/div&gt;`)[0];
#             popup_23dfd4d5c832ae3ab8f54ba3472b9bff.setContent(html_09c8f9ce7e27b5dfdfc3a7e886c7ddd3);
#
#
#         circle_marker_750437b0101a044533d2e0f2bdd028dc.bindPopup(popup_23dfd4d5c832ae3ab8f54ba3472b9bff)
#         ;
#
#
#
#
#             var circle_marker_c678274f6b536dde6cf5a3dc69a75c79 = L.circleMarker(
#                 [43.6542599, -79.3606359],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5bf8b773cdac988be23d10a3e3b79039);
#
#
#         var popup_12c8a0232f3b1df18e0fd9aaecbcef2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_901304209985372dffb17045bbead741 = $(`&lt;div id=&quot;html_901304209985372dffb17045bbead741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harbourfront, Downtown Toronto&lt;/div&gt;`)[0];
#             popup_12c8a0232f3b1df18e0fd9aaecbcef2c.setContent(html_901304209985372dffb17045bbead741);
#
#
#         circle_marker_c678274f6b536dde6cf5a3dc69a75c79.bindPopup(popup_12c8a0232f3b1df18e0fd9aaecbcef2c)
#         ;
#
#
#
#
#             var circle_marker_d8d3635164680037db4d07f9db9f6bf0 = L.circleMarker(
#                 [43.718518, -79.4647633],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;:

# %%
print('Toatl number of Borough = ', len(df['Borough'].unique()))
# Out:
# Toatl number of Borough =  11

# %%
downtown_toronto = df[df['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
print(downtown_toronto.shape)
downtown_toronto.head()
# Out:
# (19, 5)
#   Postal Code           Borough             Neighbourhood   Latitude  \
# 0         M5A  Downtown Toronto              Harbourfront  43.654260
# 1         M9A  Downtown Toronto              Queen's Park  43.667856
# 2         M5B  Downtown Toronto  Ryerson, Garden District  43.657162
# 3         M5C  Downtown Toronto            St. James Town  43.651494
# 4         M5E  Downtown Toronto               Berczy Park  43.644771
#
#    Longitude
# 0 -79.360636
# 1 -79.532242
# 2 -79.378937
# 3 -79.375418
# 4 -79.373306

# %%
address = 'Downtown Toronto ,Toronto, Ontario'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# create map of New York using latitude and longitude values
map_dwontown = folium.Map(location=[latitude, longitude], zoom_start= 11)

# add markers to map
for lat, lng, borough, neighborhood in zip(downtown_toronto['Latitude'], downtown_toronto['Longitude'], 
                                           downtown_toronto['Borough'], downtown_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dwontown)  
    
map_dwontown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b8d80597fd8fc9c47c5aa32f8d68edb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b8d80597fd8fc9c47c5aa32f8d68edb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7b8d80597fd8fc9c47c5aa32f8d68edb = L.map(
#                 &quot;map_7b8d80597fd8fc9c47c5aa32f8d68edb&quot;,
#                 {
#                     center: [43.6563221, -79.3809161],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_565b9840b05a865a0030b2ea898203f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7b8d80597fd8fc9c47c5aa32f8d68edb);
#
#
#             var circle_marker_53f31f4d9724c25d0abe0d46197d2ce7 = L.circleMarker(
#                 [43.6542599, -79.3606359],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7b8d80597fd8fc9c47c5aa32f8d68edb);
#
#
#         var popup_9a375e0ce1bd4dd05d6dc8eb3cadddbc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2f062d1db1811cda2e35baa3eb897f87 = $(`&lt;div id=&quot;html_2f062d1db1811cda2e35baa3eb897f87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harbourfront, Downtown Toronto&lt;/div&gt;`)[0];
#             popup_9a375e0ce1bd4dd05d6dc8eb3cadddbc.setContent(html_2f062d1db1811cda2e35baa3eb897f87);
#
#
#         circle_marker_53f31f4d9724c25d0abe0d46197d2ce7.bindPopup(popup_9a375e0ce1bd4dd05d6dc8eb3cadddbc)
#         ;
#
#
#
#
#             var circle_marker_fe05d383f2c970ac6d7d04d0865d7003 = L.circleMarker(
#                 [43.6678556, -79.5322424],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7b8d80597fd8fc9c47c5aa32f8d68edb);
#
#
#         var popup_02979b93b3d9a2a7804cce2ebd9d4274 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9b4ea8cc0d0954f2f851a1e253abeb39 = $(`&lt;div id=&quot;html_9b4ea8cc0d0954f2f851a1e253abeb39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queen&amp;#39;s Park, Downtown Toronto&lt;/div&gt;`)[0];
#             popup_02979b93b3d9a2a7804cce2ebd9d4274.setContent(html_9b4ea8cc0d0954f2f851a1e253abeb39);
#
#
#         circle_marker_fe05d383f2c970ac6d7d04d0865d7003.bindPopup(popup_02979b93b3d9a2a7804cce2ebd9d4274)
#         ;
#
#
#
#
#             var circle_marker_205865d8fbdf13d14510a12000bac011 = L.circleMarker(
#                 [43.6571618, -79.3789371],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7b8d80597fd8fc9c47c5aa32f8d68edb);
#
#
#         var popup_572437323568f14e3ecc8b4558fa9062 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fb1fdd57c6e549a2c782dd2ce4b8d74f = $(`&lt;div id=&quot;html_fb1fdd57c6e549a2c782dd2ce4b8d74f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ryerson, Garden District, Downtown Toronto&lt;/div&gt;`)[0];
#             popup_572437323568f14e3ecc8b4558fa9062.setContent(html_fb1fdd57c6e549a2c782dd2ce4b8d74f);
#
#
#         circle_marker_205865d8fbdf13d14510a12000bac011.bindPopup(popup_572437323568f14e3ecc8b4558fa9062)
#         ;
#
#
#
#
#             var circle_marker_b53bc8132f14cfdb63583f906e64f35d = L.circleMarker(
#                 [43.6514939, -79.3754179],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;ro

# %%
#definig the latitude and longitude using above dataframe
#CLIENT_ID = 'LM5HN3042JGPC50VLXUT2XG4L1Z4BN3DY1S5MBA5ANSVO54V' # su ID de Foursquare
#CLIENT_SECRET = 'VXEFAC1AOKO15P0VCDGWBUV0QPB4HCSV1YFEHGG4KZWXTAHS' # Secreto de Foursquare
#VERSION = '20180605' # versión de la API de Foursquare
#LIMIT = 100 # Un valor límite para la API de Foursquare
lat = downtown_toronto.loc[0, 'Latitude'] # neighborhood latitude value
lon = downtown_toronto.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = downtown_toronto.loc[0, 'Neighbourhood'] # neighborhood name
print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, lat, lon))

CLIENT_ID = 'LM5HN3042JGPC50VLXUT2XG4L1Z4BN3DY1S5MBA5ANSVO54V' # your Foursquare ID
CLIENT_SECRET = 'VXEFAC1AOKO15P0VCDGWBUV0QPB4HCSV1YFEHGG4KZWXTAHS' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 100
radius =1000
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, CLIENT_SECRET, VERSION, lat,lon, radius, LIMIT)

# gettig the venues data form Forsquare API in json format
results = requests.get(url).json()
results
# Out:
# Latitude and longitude values of Harbourfront are 43.6542599, -79.3606359.
# {'meta': {'code': 400,
#   'errorType': 'invalid_auth',
#   'errorDetail': 'Missing access credentials. See https://developer.foursquare.com/docs/api/configuration/authentication for details.',
#   'requestId': '63167d7c3314847002e7697f'},
#  'response': {}}

# %%
address = 'Downtown Toronto ,Toronto, Ontario'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# create map of New York using latitude and longitude values
map_dwontown = folium.Map(location=[latitude, longitude], zoom_start= 11)

# add markers to map
for lat, lng, borough, neighborhood in zip(downtown_toronto['Latitude'], downtown_toronto['Longitude'], 
                                           downtown_toronto['Borough'], downtown_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dwontown)  
    
map_dwontown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_700f2bd574ee56fdb062125caf531f27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_700f2bd574ee56fdb062125caf531f27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_700f2bd574ee56fdb062125caf531f27 = L.map(
#                 &quot;map_700f2bd574ee56fdb062125caf531f27&quot;,
#                 {
#                     center: [43.6563221, -79.3809161],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba4e42340899f5d2f072adf93ec2479e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_700f2bd574ee56fdb062125caf531f27);
#
#
#             var circle_marker_d3ad53047eef94d05858cea21d5cc250 = L.circleMarker(
#                 [43.6542599, -79.3606359],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_700f2bd574ee56fdb062125caf531f27);
#
#
#         var popup_4ebf4c8feee3b48d4a0a3d0971de5828 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_50bbe897f74ce3736033ab9ac9f5eed4 = $(`&lt;div id=&quot;html_50bbe897f74ce3736033ab9ac9f5eed4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harbourfront, Downtown Toronto&lt;/div&gt;`)[0];
#             popup_4ebf4c8feee3b48d4a0a3d0971de5828.setContent(html_50bbe897f74ce3736033ab9ac9f5eed4);
#
#
#         circle_marker_d3ad53047eef94d05858cea21d5cc250.bindPopup(popup_4ebf4c8feee3b48d4a0a3d0971de5828)
#         ;
#
#
#
#
#             var circle_marker_988f4632985e34f2e9dc99d652f4314e = L.circleMarker(
#                 [43.6678556, -79.5322424],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_700f2bd574ee56fdb062125caf531f27);
#
#
#         var popup_6310228d5155f3108c061085ea772f2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b4f39ca225c97599f15d3789daff2c1d = $(`&lt;div id=&quot;html_b4f39ca225c97599f15d3789daff2c1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queen&amp;#39;s Park, Downtown Toronto&lt;/div&gt;`)[0];
#             popup_6310228d5155f3108c061085ea772f2a.setContent(html_b4f39ca225c97599f15d3789daff2c1d);
#
#
#         circle_marker_988f4632985e34f2e9dc99d652f4314e.bindPopup(popup_6310228d5155f3108c061085ea772f2a)
#         ;
#
#
#
#
#             var circle_marker_313f523b6ad3495b22b19fdccd0709bc = L.circleMarker(
#                 [43.6571618, -79.3789371],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_700f2bd574ee56fdb062125caf531f27);
#
#
#         var popup_e14095b327cdf1e24fd2676c06b9053d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ea4c0dff336d6ddc11926ca0e1ccf431 = $(`&lt;div id=&quot;html_ea4c0dff336d6ddc11926ca0e1ccf431&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ryerson, Garden District, Downtown Toronto&lt;/div&gt;`)[0];
#             popup_e14095b327cdf1e24fd2676c06b9053d.setContent(html_ea4c0dff336d6ddc11926ca0e1ccf431);
#
#
#         circle_marker_313f523b6ad3495b22b19fdccd0709bc.bindPopup(popup_e14095b327cdf1e24fd2676c06b9053d)
#         ;
#
#
#
#
#             var circle_marker_be92e53eb15e455fe78c2511ed43f7c8 = L.circleMarker(
#                 [43.6514939, -79.3754179],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;ro
